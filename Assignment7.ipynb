# %%
# Task 1
integer_var = 10
float_var = 12.5
string_var = "Hello"
boolean_var = True

print(integer_var, type(integer_var))
print(float_var, type(float_var))
print(string_var, type(string_var))
print(boolean_var, type(boolean_var))

# Task 2
float_num = 19.99
int_num = int(float_num)
print(int_num, type(int_num))

integer_num = 50
string_num = str(integer_num)
print(string_num, type(string_num))

string_val = "50"
float_val = float(string_val)
print(float_val, type(float_val))

# Task 3
first_name = input("Enter first name: ")
last_name = input("Enter last name: ")
print(f"Hello, {first_name} {last_name}!")

# Task 4
age = 20
print("You are " + str(age) + " years old.")
print("Reason: Can't concatenate string and integer directly.")

# Task 5
word = input("Enter your favourite word: ")
times = int(input("How many times to repeat it? "))
print((word + " ") * times)

# Task 6
print("a -> SyntaxError")
print("b -> ValueError")
print("c -> TypeError")
