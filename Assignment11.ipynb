# %%
try:
    number = int(input("Enter a number to generate its multiplication table: "))
    print(f"\nMultiplication Table for {number} up to {number} x 12:\n")
    for i in range(1, 13):
        print(f"{number} x {i} = {number * i}")
except ValueError:
    print("Please enter a valid number.")
